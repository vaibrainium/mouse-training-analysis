# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
mouse_id = "DBM23"
session_id = "3_1"

data = pd.read_csv(rf"Y:\{mouse_id}\data\random_dot_motion\rt_directional_training\{session_id}\{mouse_id}_trial.csv")

# %%
fixation_break = []

for i in range(len(data)-9):

    temp_data = data['outcome'].iloc[i:i+10]

    fixation_break.append(np.mean(np.isnan(temp_data)))

# %%
plt.plot(fixation_break)
